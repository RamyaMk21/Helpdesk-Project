# %%
import pandas as pd

# %%
df = pd.read_csv("/content/dataset-tickets-multi-lang3-4k.csv", engine='python', on_bad_lines='warn', quotechar='"')
print(df.head())
print(df.columns)
print(df.isna().sum())
# Out:
#                                              subject  \
# 0  Problema crítico del servidor requiere atenció...
# 1     Anfrage zur Verfügbarkeit des Dell XPS 13 9310
# 2  Erro na Autocompletação de Código do IntelliJ ...
# 3            Urgent Assistance Required: AWS Service
# 4                Problème d'affichage de MacBook Air
#
#                                                 body  \
# 0  Es necesaria una investigación inmediata sobre...
# 1  Sehr geehrter Kundenservice,\n\nich hoffe, die...
# 2  Prezado Suporte ao Cliente <name>,\n\nEstou es...
# 3  Dear IT Services Support Team, \n\nI am reachi...
# 4  Cher équipe de support du magasin en ligne Tec...
#
#                                               answer      type  \
# 0  Estamos investigando urgentemente el problema ...  Incident
# 1  Sehr geehrter <name>,\n\nvielen Dank, dass Sie...   Request
# 2  Prezado <name>,\n\nObrigado por entrar em cont...  Incident
# 3  Dear <name>,\n\nThank you for reaching out reg...   Request
# 4  Cher <name>,\n\nMerci de nous avoir contactés ...  Incident
#
#                queue priority language      business_type              tag_1  \
# 0  Technical Support     high       es        IT Services       Urgent Issue
# 1   Customer Service      low       de  Tech Online Store      Sales Inquiry
# 2  Technical Support     high       pt        IT Services  Technical Support
# 3         IT Support     high       en        IT Services         IT Support
# 4    Product Support      low       fr  Tech Online Store  Technical Support
#
#                 tag_2                 tag_3             tag_4  \
# 0  Service Disruption       Incident Report  Service Recovery
# 1     Product Support      Customer Service       Order Issue
# 2        Software Bug    Problem Resolution      Urgent Issue
# 3        Urgent Issue  Service Notification    Cloud Services
# 4     Product Support      Hardware Failure  Service Recovery
#
#                    tag_5               tag_6               tag_7 tag_8  tag_9
# 0     System Maintenance                 NaN                 NaN   NaN    NaN
# 1  Returns and Exchanges                 NaN                 NaN   NaN    NaN
# 2             IT Support                 NaN                 NaN   NaN    NaN
# 3     Problem Resolution  Technical Guidance  Performance Tuning   NaN    NaN
# 4        Routine Request                 NaN                 NaN   NaN    NaN
# Index(['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language',
#        'business_type', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6',
#        'tag_7', 'tag_8', 'tag_9'],
#       dtype='object')
# subject           350
# body                2
# answer              1
# type                1
# queue               1
# priority            1
# language            1
# business_type       1
# tag_1               1
# tag_2               1
# tag_3               1
# tag_4               2
# tag_5             507
# tag_6            1396
# tag_7            2282
# tag_8            2863
# tag_9            3063
# dtype: int64

# %%
# Fill missing subject with empty string
df['subject'] = df['subject'].fillna("")

# Basic text cleaning
def clean_text(text):
    text = str(text).strip()
    return text

df['subject'] = df['subject'].apply(clean_text)
df['body'] = df['body'].apply(clean_text)

# One combined text column
df['full_text'] = df['subject'] + " " + df['body']

# %%
tag_cols = [f"tag_{i}" for i in range(1, 10)]

def get_main_tag(row):
    for c in tag_cols:
        val = row[c]
        if pd.notna(val) and str(val).strip() != "":
            return val
    return None

df['main_tag'] = df.apply(get_main_tag, axis=1)

# %%
lang_counts = df['language'].value_counts()
print(lang_counts)
# Out:
# language
# en    1121
# de     636
# es     600
# fr     361
# pt     344
# Name: count, dtype: int64

# %%
print(df['type'].value_counts())
print(df['priority'].value_counts())
# Out:
# type
# Incident    1209
# Request      852
# Problem      662
# Change       339
# Name: count, dtype: int64
# priority
# high      1262
# medium    1232
# low        568
# Name: count, dtype: int64

# %%
pd.crosstab(df['language'], df['type'])
# Out:
# type      Change  Incident  Problem  Request
# language
# de            66       241      149      180
# en           129       474      217      301
# es            58       229      131      182
# fr            45       122       85      109
# pt            41       143       80       80

# %%
pd.crosstab(df['main_tag'], df['priority'])
# Out:
# priority               high  low  medium
# main_tag
# Account Assistance        2    1       5
# Account Security          1    2       0
# Billing Issue            79   38     111
# Critical Failure          3    0       0
# Customer Feedback         1    0       1
# Customer Service         13   33      45
# Data Breach               3    0       0
# Database Issue            1    0       0
# Emergency Issue           1    0       0
# Feature Request           1    5       0
# General Inquiry           1    4       0
# Hardware Failure          7    1       3
# Human Resources           0    1       2
# IT Support               89   50      71
# Incident Report           1    0       0
# Login Issue              16    0       5
# Network Issue            63    1      28
# Order Issue               2    1       2
# Password Reset            3    0       1
# Payment Processing        0    1       2
# Performance Tuning        0    6       2
# Product Support          41   32      67
# Refund Request            3    2       0
# Return and Exchanges      0    1       0
# Returns and Exchanges    29   58      73
# Sales Inquiry             0   17      22
# Service Disruption       38    2       4
# Service Maintenance       0    0       2
# Service Outage           64    0       9
# Shipment Delay            1    0       0
# Software Bug             13    3       8
# System Crash              2    0       0
# System Maintenance        1    1       0
# Technical Guidance        1    2       2
# Technical Support       610  304     734
# Urgent Issue            165    0      25
# Warranty Claim            7    2       8

# %%
df_clean = df[['subject', 'body', 'answer', 'type', 'queue',
               'priority', 'language', 'business_type',
               'main_tag'] + tag_cols + ['full_text']]

df_clean.to_csv("tickets_clean.csv", index=False)

# %%
pip install pymysql sqlalchemy
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.44)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
from sqlalchemy import create_engine

# Create SQLite DB inside Colab
engine = create_engine("sqlite:///tickets.db")

# %%
df.to_sql("tickets_clean", con=engine, if_exists="replace", index=False)

print("Table uploaded successfully!")
# Out:
# Table uploaded successfully!

# %%
import pandas as pd

pd.read_sql("SELECT COUNT(*) FROM tickets_clean", engine)
# Out:
#    COUNT(*)
# 0      3063
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['COUNT(*)']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'COUNT(*)'}, axis=1)
#               .sort_values('COUNT(*)', ascending=True))
#   xs = counted['COUNT(*)']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('COUNT(*)', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('COUNT(*)')
# _ = plt.ylabel('count()')

# %%
from google.colab import files
files.download("tickets.db")

# %%
df.to_csv("tickets_clean.csv", index=False)
from google.colab import files
files.download("tickets_clean.csv")
